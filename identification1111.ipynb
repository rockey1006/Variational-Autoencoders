# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/Variational-Autoencoders/blob/master/identification1111.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/rockey1006/classifier_1110.git
# Out:
# Cloning into 'classifier_1110'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/vgg_face_weights.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('vgg_face_weights/')

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/new_A1A.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('new_A1A/')

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/new_A1.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('new_A1/')

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/new_A2.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('new_A2/')

# %%
# !python /content/classifier_1110/Face2020.py
# Out:
# 2020-11-11 09:33:54.089326: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-11 09:34:00.843186: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-11 09:34:00.843582: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-11 09:34:00.844066: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-11-11 09:34:00.844130: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python /content/classifier_1110/Face2020.py
# Out:
# 2020-11-11 09:36:47.344018: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-11 09:36:50.208507: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-11 09:36:50.208704: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-11 09:36:50.209148: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-11-11 09:36:50.209201: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
import numpy as np
import os
 
img_path='/content/new_A1'
 
img_list=sorted(os.listdir(img_path))	#

img_nums=len(img_list)

# %%
c = 0
for i in range(img_nums):
    c = c+1
 

    if c == 15 or c==26 or c==37 or c==43 or c==59 or c==69 or c==97 or c==119 or c==122 or c==134 or c==150 or c==183 or c==209 or c==211 or c==225 or c==240 or c==244 or c==300 or c==305 or c==322 or c==323 or c==364 or c==376 or c==388 or c==389 or c==393 or c==402 or c==418:
      print(img_list[i])
