# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/Variational-Autoencoders/blob/master/LFW_one_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/LFW_A.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('LFW_A')

# %%
import os,sys
import random
import shutil
from PIL import Image
 

def random_copyfile(srcPath,dstPath):
    for name_file in os.listdir(srcPath):
        temp = []
        for img_file in os.listdir(srcPath+name_file):      
            temp.append(img_file)
        if len(temp) == 0:
            continue
        randomfile = random.choice(temp)
        path = os.path.join(srcPath+name_file+'/'+randomfile)
        with open(path, 'rb') as rstream:
                container = rstream.read()
                path1 = os.path.join(dstPath+name_file)
                if not os.path.exists(path1):
                  os.mkdir(path1)
                  path1 = os.path.join(dstPath+name_file+'/'+randomfile)
  
                with open(path1, 'wb') as wstream:
                    wstream.write(container)

 

 

srcPath='/content/LFW_A/LFW_A/'
dstPath = '/content/new_A2/'

# %%
# !git clone https://github.com/rockey1006/classifier.git
# Out:
# Cloning into 'classifier'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 17 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (17/17), done.

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/vgg_face_weights.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('vgg_face_weights/')

# %%
# !python /content/classifier/Face2020.py
'''      print("Evaluate on test data")
        results = classifier_model.evaluate(x_test, y_test, batch_size=128)
        print("test loss, test acc:", results)
        print("wrong data")
        predictions = classifier_model.predict_classes(x_test)
        wrong = np.where(predictions != y_test)
        print("positions:", wrong)
'''
# Out:
# 2020-11-10 05:59:01.270676: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-10 05:59:08.030116: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-10 05:59:08.030536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-10 05:59:08.031236: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-11-10 05:59:08.031298: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-10 05:59:08.031374: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-11-10 05:59:08.167502: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-11-10 05:59:08.167685: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-11-10 05:59:08.167734: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-11-10 05:59:08.195994: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-11-10 05:59:08.196118: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-11-10 05:59:08.196255: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-10 05:59:08.196949: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-10 05:59:08.197498: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-11-10 05:59:08.267173: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2200000000 Hz
# 2020-11-10 05:59:08.267404: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2779ec40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-10 05:59:08.267440: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-11-10 05:59:08.274929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-10 05:59:08.275601: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2779ee00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-11-10 05:59:08.275630: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-11-10 05:59:08.275876: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-10 05:59:08.276421: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-11-10 05:59:08.276506: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-10 05:59:08.276530: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-11-10 05:59:08.276573: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-11-10 05:59:08.276596: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-11-10 05:59:08.276612: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-11-10 05:59:08.276639: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-11-10 05:59:08.276669: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-11-10 05:59:08.276762: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-10 05:59:08.277618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-10 05:59:08.278831: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-11-10 05:59:08.283067: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-10 05:59:12.364386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-10 05:59:12.364456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-11-10 05:59:12.364468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-11-10 05:59:12.372826: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-10 05:59:12.373499: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-10 05:59:12.374084: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-11-10 05:59:12.374132: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14455 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# model loaded-------------
# 2020-11-10 05:59:13.156907: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-11-10 05:59:13.330946: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# (432, 2622)
# (432,)
# Epoch 1/100
# 14/14 [==============================] - 0s 4ms/step - loss: 9.0338 - accuracy: 0.0000e+00
# Epoch 2/100
# 14/14 [==============================] - 0s 3ms/step - loss: 8.0783 - accuracy: 0.0093
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.1518 - accuracy: 0.0231
# Epoch 4/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.3942 - accuracy: 0.0602
# Epoch 5/100
# 14/14 [==============================] - 0s 4ms/step - loss: 5.8352 - accuracy: 0.1065
# Epoch 6/100
# 14/14 [==============================] - 0s 4ms/step - loss: 5.3898 - accuracy: 0.2199
# Epoch 7/100
# 14/14 [==============================] - 0s 3ms/step - loss: 5.0103 - accuracy: 0.3611
# Epoch 8/100
# 14/14 [==============================] - 0s 4ms/step - loss: 4.7520 - accuracy: 0.4907
# Epoch 9/100
# 14/14 [==============================] - 0s 4ms/step - loss: 4.4667 - accuracy: 0.5880
# Epoch 10/100
# 14/14 [==============================] - 0s 4ms/step - loss: 4.2391 - accuracy: 0.7014
# Epoch 11/100
# 14/14 [==============================] - 0s 3ms/step - loss: 4.0767 - accuracy: 0.7731
# Epoch 12/100
# 14/14 [==============================] - 0s 4ms/step - loss: 3.9007 - accuracy: 0.8009
# Epoch 13/100
# 14/14 [==============================] - 0s 4ms/step - loss: 3.7067 - accuracy: 0.9005
# Epoch 14/100
# 14/14 [==============================] - 0s 4ms/step - loss: 3.6060 - accuracy: 0.9097
# Epoch 15/100
# 14/14 [==============================] - 0s 3ms/step - loss: 3.4673 - accuracy: 0.9236
# Epoch 16/100
# 14/14 [==============================] - 0s 4ms/step - loss: 3.2943 - accuracy: 0.9537
# Epoch 17/100
# 14/14 [==============================] - 0s 4ms/step - loss: 3.2051 - accuracy: 0.9676
# Epoch 18/100
# 14/14 [==============================] - 0s 3ms/step - loss: 3.0833 - accuracy: 0.9722
# Epoch 19/100
# 14/14 [==============================] - 0s 3ms/step - loss: 2.9692 - accuracy: 0.9861
# Epoch 20/100
# 14/14 [==============================] - 0s 3ms/step - loss: 2.8983 - accuracy: 0.9907
# Epoch 21/100
# 14/14 [==============================] - 0s 4ms/step - loss: 2.7633 - accuracy: 0.9815
# Epoch 22/100
# 14/14 [==============================] - 0s 4ms/step - loss: 2.6772 - accuracy: 0.9907
# Epoch 23/100
# 14/14 [==============================] - 0s 3ms/step - loss: 2.5699 - accuracy: 0.9954
# Epoch 24/100
# 14/14 [==============================] - 0s 4ms/step - loss: 2.4714 - accuracy: 0.9977
# Epoch 25/100
# 14/14 [==============================] - 0s 4ms/step - loss: 2.4450 - accuracy: 0.9931
# Epoch 26/100
# 14/14 [==============================] - 0s 4ms/step - loss: 2.3301 - accuracy: 0.9954
# Epoch 27/100
# 14/14 [==============================] - 0s 4ms/step - loss: 2.2661 - accuracy: 0.9954
# Epoch 28/100
# 14/14 [==============================] - 0s 4ms/step - loss: 2.1694 - accuracy: 0.9977
# Epoch 29/100
# 14/14 [==============================] - 0s 4ms/step - loss: 2.0900 - accuracy: 0.9977
# Epoch 30/100
# 14/14 [==============================] - 0s 4ms/step - loss: 2.0115 - accuracy: 0.9954
# Epoch 31/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.9168 - accuracy: 1.0000
# Epoch 32/100
# 14/14 [==============================] - 0s 3ms/step - loss: 1.8690 - accuracy: 1.0000
# Epoch 33/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.7884 - accuracy: 0.9977
# Epoch 34/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.7308 - accuracy: 0.9977
# Epoch 35/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.6781 - accuracy: 0.9977
# Epoch 36/100
# 14/14 [==============================] - 0s 3ms/step - loss: 1.5542 - accuracy: 0.9977
# Epoch 37/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.5359 - accuracy: 0.9977
# Epoch 38/100
# 14/14 [==============================] - 0s 3ms/step - loss: 1.4751 - accuracy: 1.0000
# Epoch 39/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.4013 - accuracy: 1.0000
# Epoch 40/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.3414 - accuracy: 0.9977
# Epoch 41/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.2899 - accuracy: 1.0000
# Epoch 42/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.2618 - accuracy: 1.0000
# Epoch 43/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.1887 - accuracy: 0.9977
# Epoch 44/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.1578 - accuracy: 0.9977
# Epoch 45/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.0720 - accuracy: 1.0000
# Epoch 46/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.0740 - accuracy: 0.9977
# Epoch 47/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.0299 - accuracy: 1.0000
# Epoch 48/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.9692 - accuracy: 0.9977
# Epoch 49/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.9116 - accuracy: 1.0000
# Epoch 50/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.9224 - accuracy: 1.0000
# Epoch 51/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.8205 - accuracy: 0.9977
# Epoch 52/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.8273 - accuracy: 1.0000
# Epoch 53/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.8119 - accuracy: 1.0000
# Epoch 54/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.7756 - accuracy: 1.0000
# Epoch 55/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.7224 - accuracy: 1.0000
# Epoch 56/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6762 - accuracy: 1.0000
# Epoch 57/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6757 - accuracy: 0.9977
# Epoch 58/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6403 - accuracy: 1.0000
# Epoch 59/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5927 - accuracy: 1.0000
# Epoch 60/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5860 - accuracy: 1.0000
# Epoch 61/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5691 - accuracy: 1.0000
# Epoch 62/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5501 - accuracy: 0.9977
# Epoch 63/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5490 - accuracy: 1.0000
# Epoch 64/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4957 - accuracy: 1.0000
# Epoch 65/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4598 - accuracy: 1.0000
# Epoch 66/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4672 - accuracy: 1.0000
# Epoch 67/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4605 - accuracy: 1.0000
# Epoch 68/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4421 - accuracy: 1.0000
# Epoch 69/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4015 - accuracy: 1.0000
# Epoch 70/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3883 - accuracy: 1.0000
# Epoch 71/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3825 - accuracy: 1.0000
# Epoch 72/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3710 - accuracy: 1.0000
# Epoch 73/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3519 - accuracy: 1.0000
# Epoch 74/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3576 - accuracy: 0.9977
# Epoch 75/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3460 - accuracy: 1.0000
# Epoch 76/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3168 - accuracy: 1.0000
# Epoch 77/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3201 - accuracy: 1.0000
# Epoch 78/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3077 - accuracy: 1.0000
# Epoch 79/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2943 - accuracy: 1.0000
# Epoch 80/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2680 - accuracy: 1.0000
# Epoch 81/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2732 - accuracy: 1.0000
# Epoch 82/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2704 - accuracy: 1.0000
# Epoch 83/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2625 - accuracy: 1.0000
# Epoch 84/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2630 - accuracy: 1.0000
# Epoch 85/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2581 - accuracy: 1.0000
# Epoch 86/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2416 - accuracy: 1.0000
# Epoch 87/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2515 - accuracy: 1.0000
# Epoch 88/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2278 - accuracy: 1.0000
# Epoch 89/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2184 - accuracy: 1.0000
# Epoch 90/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2093 - accuracy: 1.0000
# Epoch 91/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2152 - accuracy: 1.0000
# Epoch 92/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1987 - accuracy: 1.0000
# Epoch 93/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1913 - accuracy: 1.0000
# Epoch 94/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1830 - accuracy: 1.0000
# Epoch 95/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1742 - accuracy: 1.0000
# Epoch 96/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1779 - accuracy: 1.0000
# Epoch 97/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1824 - accuracy: 1.0000
# Epoch 98/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1681 - accuracy: 1.0000
# Epoch 99/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1696 - accuracy: 1.0000
# Epoch 100/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1689 - accuracy: 1.0000
# Evaluate on test data
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6796 - accuracy: 0.9213
# test loss, test acc: [0.6796066761016846, 0.9212962985038757]
# wrong data
# WARNING:tensorflow:From /content/classifier/FaceModel.py:79: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# positions: (array([ 15,  30,  37,  59,  63,  89,  94, 104, 115, 131, 139, 182, 193,
#        211, 218, 228, 256, 269, 281, 305, 312, 314, 318, 327, 333, 380,
#        381, 385, 387, 391, 392, 395, 420, 427]),)
# done..
