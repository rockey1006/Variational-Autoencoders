# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/Variational-Autoencoders/blob/master/1026_one_shot_accuracy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/LFW1026.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('LFW')

# %%
#form one-shot dataset
import os
src_path = '/content/LFW/Align/'
target_path = '/content/new1/'
def copy_picture(src_path, target_path):
    for name_file in os.listdir(src_path):
      count = 0
      for img_file in os.listdir(src_path+name_file):
        count = count+1
      if count == 1:
        for img_file in os.listdir(src_path+name_file):
          path = os.path.join(src_path+name_file+'/'+img_file)
          with open(path, 'rb') as rstream:
                container = rstream.read()
                path1 = os.path.join(target_path+name_file)
                if not os.path.exists(path1):
                  os.mkdir(path1)
                path1 = os.path.join(target_path+name_file+'/'+img_file)
                with open(path1, 'wb') as wstream:
                    wstream.write(container)

# %%
copy_picture(src_path, target_path)

# %%
# !zip -r /content/file.zip /content/new1
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/new1/Brandon_Jones/Brandon_Jones_0001_0.png (deflated 0%)
#   adding: content/new1/Julio_Rossi/ (stored 0%)
#   adding: content/new1/Julio_Rossi/Julio_Rossi_0001_0.png (deflated 0%)
#   adding: content/new1/Sabah_Al-Ahmad_Al-Jaber_Al-Sabah/ (stored 0%)
#   adding: content/new1/Sabah_Al-Ahmad_Al-Jaber_Al-Sabah/Sabah_Al-Ahmad_Al-Jaber_Al-Sabah_0001_0.png (deflated 0%)
#   adding: content/new1/Jose_Luis_Chilavert/ (stored 0%)
#   adding: content/new1/Jose_Luis_Chilavert/Jose_Luis_Chilavert_0001_0.png (deflated 0%)
#   adding: content/new1/William_Murabito/ (stored 0%)
#   adding: content/new1/William_Murabito/William_Murabito_0001_0.png (deflated 0%)
#   adding: content/new1/Tony_Elias/ (stored 0%)
#   adding: content/new1/Tony_Elias/Tony_Elias_0001_0.png (deflated 0%)
#   adding: content/new1/George_Bovell/ (stored 0%)
#   adding: content/new1/George_Bovell/George_Bovell_0001_0.png (deflated 0%)
# ...

# %%
from google.colab import files
files.download("/content/file.zip")

# %%
# !git clone https://github.com/rockey1006/classifier.git
# Out:
# Cloning into 'classifier'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 17 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (17/17), done.

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/vgg_face_weights.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('vgg_face_weights/')

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/LFW1shot.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/content/one/')

# %%
# !python /content/classifier/Face2020.py
# Out:
# 2020-10-26 04:48:19.959840: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-26 04:48:27.635103: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-26 04:48:27.635512: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-26 04:48:27.636152: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-26 04:48:27.636207: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...
